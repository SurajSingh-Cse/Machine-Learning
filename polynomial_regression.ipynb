# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df=pd.read_csv(r"polynomial.csv")
df.head(2)
# Out:
#           x           y
# 0  1.409445    5.275026
# 1 -9.337377  212.625146

# %%
df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
sns.scatterplot(x="x",y="y",data=df)
plt.show()

# %%
x=df[["x"]]
y=df["y"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x=pf.transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 99.36856235778967

# %%
prd=lr.predict(x)

# %%
sns.scatterplot(x="x",y="y",data=df)
plt.plot(df["x"],prd,c='green')
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["org","predict"])

plt.show()

# %%
test=pf.transform([[45]])
test
# Out:
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.000e+00, 4.500e+01, 2.025e+03]])

# %%
lr.predict(test)
# Out:
# array([3910.44679892])
