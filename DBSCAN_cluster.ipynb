# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import make_moons

df=pd.read_csv(r"dbscan_sample_dataset.csv")
df.head()
# Out:
#           x         y
# 0  2.149014  1.958521
# 1  2.194307  2.456909
# 2  1.929754  1.929759
# 3  2.473764  2.230230
# 4  1.859158  2.162768

# %%
X = df[["x", "y"]].values

# %%
sns.scatterplot(x="x", y="y", data=df, color="blue", alpha=0.5)
plt.title("DBSCAN Sample Dataset")
plt.show()

# %%
sns.scatterplot(x=X[:,0], y=X[:,1])
plt.title('Moons Dataset')
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
ds = DBSCAN(eps=0.5, min_samples=5)
df["predict"] = ds.fit_predict(X)

# %%
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, palette='Set1', s=50, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x="x", y="y",data=df, hue="predict", palette='Set1', s=50, alpha=0.5)
plt.title('DBSCAN Clustering')
plt.show()
