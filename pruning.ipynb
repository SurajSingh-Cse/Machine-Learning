# %%
#import library
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions


#load dataset
df= pd.read_csv(r"decision_tree2.csv")
df.head()
# Out:
#    Age  Salary  Purchased
# 0   56   45342          0
# 1   46   57157          1
# 2   32   87863          1
# 3   25   72083          0
# 4   38   85733          1

# %%
sns.scatterplot(x="Age",y="Salary", data=df,hue="Purchased")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["Purchased"]

# %%
sc=StandardScaler()
sc.fit(x)
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# pre pruning

# %%
dt=DecisionTreeClassifier(max_depth=5)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt.score(x_test,y_test)*100
# Out:
# 100.0

# %%
dt.score(x_train,y_train)*100
# Out:
# 100.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# c:\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(50,50))
plot_tree(dt)
plt.show()

# %% [markdown]
# post pruning

# %%
for i in range(1,20):
    dt2=DecisionTreeClassifier(max_depth=i)
    dt2.fit(x_train,y_train)
    print(dt2.score(x_train,y_train)*100,dt2.score(x_test,y_test)*100,i)
# Out:
# 81.25 87.5 1
# 100.0 100.0 2
# 100.0 100.0 3
# 100.0 100.0 4
# 100.0 100.0 5
# 100.0 100.0 6
# 100.0 100.0 7
# 100.0 100.0 8
# 100.0 100.0 9
# 100.0 100.0 10
# 100.0 100.0 11
# 100.0 100.0 12
# 100.0 100.0 13
# 100.0 100.0 14
# 100.0 100.0 15
# 100.0 100.0 16
# 100.0 100.0 17
# 100.0 100.0 18
# 100.0 100.0 19
